# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input

# %%
df = pd.read_csv("Churn_treino.csv", sep=";")
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0             619    France  Female   42       2         0              1
# 1             608     Spain  Female   41       1   8380786              1
# 2             502    France  Female   42       8   1596608              3
# 3             699    France  Female   39       1         0              2
# 4             850     Spain  Female   43       2  12551082              1
# ...           ...       ...     ...  ...     ...       ...            ...
# 9995          771    France    Male   39       5         0              2
# 9996          516    France    Male   35      10   5736961              1
# 9997          709    France  Female   36       7         0              1
# 9998          772   Germany    Male   42       3   7507531              2
# 9999          792    France  Female   28       4  13014279              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1         10134888       1
# 1             0               1         11254258       0
# 2             1               0         11393157       1
# 3             0               0          9382663       0
# 4             1               1           790841       0
# ...         ...             ...              ...     ...
# 9995          1               0          9627064       0
# 9996          1               1         10169977       0
# 9997          0               1          4208558       1
# 9998          1               0          9288852       1
# 9999          1               0          3819078       0
#
# [10000 rows x 11 columns]

# %%
X = df.drop("Exited", axis=1)
y = df["Exited"]

# %%
standarscaler = StandardScaler()
numerical = X.select_dtypes(include=['int64', 'float64']).columns
X[numerical] = standarscaler.fit_transform(X[numerical])

# %%
X
# Out:
#       CreditScore Geography  Gender       Age    Tenure   Balance  \
# 0       -0.326221    France  Female  0.293517 -1.041760 -1.110553
# 1       -0.440036     Spain  Female  0.198164 -1.387538  0.222782
# 2       -1.536794    France  Female  0.293517  1.032908 -0.856542
# 3        0.501521    France  Female  0.007457 -1.387538 -1.110553
# 4        2.063884     Spain  Female  0.388871 -1.041760  0.886252
# ...           ...       ...     ...       ...       ...       ...
# 9995     1.246488    France    Male  0.007457 -0.004426 -1.110553
# 9996    -1.391939    France    Male -0.373958  1.724464 -0.197835
# 9997     0.604988    France  Female -0.278604  0.687130 -1.110553
# 9998     1.256835   Germany    Male  0.293517 -0.695982  0.083852
# 9999     1.463771    France  Female -1.041433 -0.350204  0.959944
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.170614
# 1         -0.911583  -1.547768        0.970243         0.353281
# 2          2.527057   0.646092       -1.030670         0.375948
# 3          0.807737  -1.547768       -1.030670         0.047859
# 4         -0.911583   0.646092        0.970243        -1.354223
# ...             ...        ...             ...              ...
# 9995       0.807737   0.646092       -1.030670         0.087743
# 9996      -0.911583   0.646092        0.970243         0.176340
# 9997      -0.911583  -1.547768        0.970243        -0.796492
# 9998       0.807737   0.646092       -1.030670         0.032551
# 9999      -0.911583   0.646092       -1.030670        -0.860051
#
# [10000 rows x 10 columns]

# %%
labelencoder = LabelEncoder()
categorical = X.select_dtypes(include='object').columns
for col in categorical:
  X[col] = labelencoder.fit_transform(X[col])

# %%
X
# Out:
#       CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 0       -0.326221          0       0  0.293517 -1.041760 -1.110553
# 1       -0.440036          2       0  0.198164 -1.387538  0.222782
# 2       -1.536794          0       0  0.293517  1.032908 -0.856542
# 3        0.501521          0       0  0.007457 -1.387538 -1.110553
# 4        2.063884          2       0  0.388871 -1.041760  0.886252
# ...           ...        ...     ...       ...       ...       ...
# 9995     1.246488          0       1  0.007457 -0.004426 -1.110553
# 9996    -1.391939          0       1 -0.373958  1.724464 -0.197835
# 9997     0.604988          0       0 -0.278604  0.687130 -1.110553
# 9998     1.256835          1       1  0.293517 -0.695982  0.083852
# 9999     1.463771          0       0 -1.041433 -0.350204  0.959944
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.170614
# 1         -0.911583  -1.547768        0.970243         0.353281
# 2          2.527057   0.646092       -1.030670         0.375948
# 3          0.807737  -1.547768       -1.030670         0.047859
# 4         -0.911583   0.646092        0.970243        -1.354223
# ...             ...        ...             ...              ...
# 9995       0.807737   0.646092       -1.030670         0.087743
# 9996      -0.911583   0.646092        0.970243         0.176340
# 9997      -0.911583  -1.547768        0.970243        -0.796492
# 9998       0.807737   0.646092       -1.030670         0.032551
# 9999      -0.911583   0.646092       -1.030670        -0.860051
#
# [10000 rows x 10 columns]

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
modelo = Sequential()
modelo.add(Input(shape=(X_treino.shape[1],)))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=32, activation='relu'))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=64, activation='relu'))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=1, activation='sigmoid'))

# %%
modelo.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
modelo.fit(X_treino, y_treino, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6612 - loss: 0.6366
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7985 - loss: 0.5017
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4979
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7936 - loss: 0.4821
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7966 - loss: 0.4839
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8147 - loss: 0.4522
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8045 - loss: 0.4634
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8121 - loss: 0.4467
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4594
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8057 - loss: 0.4526
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.4448
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.4466
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8082 - loss: 0.4499
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8187 - loss: 0.4431
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8142 - loss: 0.4459
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8123 - loss: 0.4400
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8174 - loss: 0.4372
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8011 - loss: 0.4453
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8157 - loss: 0.4326
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8138 - loss: 0.4434
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8140 - loss: 0.4424
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8189 - loss: 0.4332
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8109 - loss: 0.4460
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8106 - loss: 0.4367
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8190 - loss: 0.4187
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8202 - loss: 0.4262
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4268
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8237 - loss: 0.4194
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8239 - loss: 0.4267
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8169 - loss: 0.4269
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8240 - loss: 0.4178
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8208 - loss: 0.4254
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8267 - loss: 0.4189
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8221 - loss: 0.4291
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8249 - loss: 0.4192
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8270 - loss: 0.4263
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8293 - loss: 0.4170
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8185 - loss: 0.4300
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8185 - loss: 0.4338
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8187 - loss: 0.4260
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8275 - loss: 0.4214
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8184 - loss: 0.4329
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8295 - loss: 0.4170
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.4395
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8241 - loss: 0.4185
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8247 - loss: 0.4225
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8261 - loss: 0.4191
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8253 - loss: 0.4180
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.4165
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8197 - loss: 0.4261

# %%
previsoes = modelo.predict(X_teste)
previsoes
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.22143485],
#        [0.27214974],
#        [0.27206331],
#        ...,
#        [0.14499286],
#        [0.31559983],
#        [0.41044167]], dtype=float32)

# %%
y_pred = (previsoes > 0.5).astype('int32')
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int32)

# %%
print('Acurácia: ', accuracy_score(y_teste, y_pred))
print('F1: ', f1_score(y_teste, y_pred))
print('Recall: ', recall_score(y_teste, y_pred))
print('Matriz de Confusão: ', confusion_matrix(y_teste, y_pred))
# Out:
# Acurácia:  0.8446666666666667
# F1:  0.4218362282878412
# Recall:  0.27375201288244766
# Matriz de Confusão:  [[2364   15]
#  [ 451  170]]
